# %% [markdown]
# # nmi | spring 2024
# ## special lecture 04 : neural networks, briefly
# ## your name

# %% [markdown]
# ### lab three.

# %% [markdown]
# not soup yet.
# </br></br>
#
# 1. wait for it.
# </br>
#
# <font color=red>this is the response for <b>final q25</b>.</font>
# </br>
