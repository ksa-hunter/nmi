# %% [markdown]
# # nmi | spring 2024
# ## special lecture 04 : neural networks, briefly
# ## your name

# %% [markdown]
# ### lab two.

# %% [markdown]
# code **what i say**, not *what i do*.
# </br></br>
#
# 1. pay attention.
# </br>
#
# <font color=red>this is the response for <b>final q23</b>.</font>
# </br>

# %% [markdown]
# ###### code, prep

# %%
# lies lies lies
# !pip install -U scikit-learn
# lies lies lies

# %%
# google drive stuff
google_drive = "/content/drive/My Drive/Colab Notebooks/" # colab home directory
local = "" # if subdirectory; eg, "test/" # yes, "/" is important
path = google_drive + local

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ###### code

# %%
# some stuff i havent given you yet

# %%
# your class

# %%
# an instance of your class
